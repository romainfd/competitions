# %%
# %load_ext autoreload
# %autoreload 2

import json
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import set_matplotlib_formats, clear_output
set_matplotlib_formats('retina')
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12.0, 7.0)

from utils import load_datasets

# %%
datasets = load_datasets()

# %%
fig, axes = plt.subplots(3, 2, figsize=(25, 15))
axes = axes.flatten()
for i in range(6):
    datasets[i].plot_domain(axes[i])
plt.tight_layout()
plt.show()

# %%
for dataset in datasets:
    print(dataset.str_stats)
# Out:
# id: 1
#   - Number of workers: 4
#   - Number of domains: 2
#   - Number of transports morning: 6
#   - Number of transports evening: 4
#
# id: 2
#   - Number of workers: 105
#   - Number of domains: 5
#   - Number of transports morning: 30
#   - Number of transports evening: 30
#
# id: 3
#   - Number of workers: 10000
#   - Number of domains: 10
#   - Number of transports morning: 5000
#   - Number of transports evening: 5000
#
# id: 4
#   - Number of workers: 15756
#   - Number of domains: 20
#   - Number of transports morning: 999
#   - Number of transports evening: 999
#
# id: 5
#   - Number of workers: 22037
#   - Number of domains: 20
#   - Number of transports morning: 221
#   - Number of transports evening: 221
#
# id: 6
#   - Number of workers: 50000
#   - Number of domains: 50
#   - Number of transports morning: 999
#   - Number of transports evening: 999

# %%
fig, axes = plt.subplots(3, 2, figsize=(25, 15))
axes = axes.flatten()
for i in range(6):
    datasets[i].plot_transport_morning(axes[i])
plt.tight_layout()
plt.show()
